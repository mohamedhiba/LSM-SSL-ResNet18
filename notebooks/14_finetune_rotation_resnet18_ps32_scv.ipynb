# %% [markdown]
# # Fine-tune Rotation-pretrained ResNet-18, ps32 SCV
#
# This notebook fine-tunes a binary ResNet-18 classifier initialized from the Rotation Prediction SSL encoder checkpoint. It uses the same ps32 5-cluster spatial cross-validation protocol as the scratch, masked-reconstruction, contrastive, and Jigsaw ResNet-18 models.

# %% [markdown]
# ## 1. Purpose and experiment configuration
#
# This notebook performs supervised fine-tuning only. It does not rerun Rotation SSL pretraining, does not modify any SSL checkpoint, and does not generate susceptibility maps.
#
# Scientific warning: Rotation pretraining learned a strong geometric signal. Downstream fine-tuning results should be interpreted carefully because rotation prediction may emphasize orientation cues that are not necessarily physically invariant in landslide susceptibility modeling.

# %%
from pathlib import Path
import os

os.environ.setdefault("CUBLAS_WORKSPACE_CONFIG", ":4096:8")

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

model_name = "rotation_resnet18"
pretraining = "rotation"
patch_size = 32
random_seed = 42
val_fraction = 0.2
batch_size = 16
encoder_learning_rate = 1e-5
head_learning_rate = 1e-4
weight_decay = 1e-4
max_epochs = 100
early_stopping_patience = 15
gradient_clip_norm = 5.0
dropout = 0.4

patch_index_csv = PROJECT_ROOT / "data/processed/patches/labeled_patch_index_ps32_common_balanced.csv"
raster_dir = PROJECT_ROOT / "data/processed/rasters_cleaned"
encoder_checkpoint_path = PROJECT_ROOT / "checkpoints/ssl_pretrained/rotation/resnet18_rotation_ps32_encoder_best.pt"
output_root = PROJECT_ROOT / "outputs/R1_ssl_task_comparison/rotation"
figure_root = PROJECT_ROOT / "figures/R1_ssl_task_comparison/rotation"
checkpoint_dir = PROJECT_ROOT / "checkpoints/finetuned/rotation_resnet18"

reference_metrics = {
    "scratch": {"mean_auc": 0.778842, "std_auc": 0.104754, "worst_fold_auc": 0.624023},
    "masked_recon": {"mean_auc": 0.820912, "std_auc": 0.043011, "worst_fold_auc": 0.786325},
    "contrastive": {"mean_auc": 0.838008, "std_auc": 0.084941, "worst_fold_auc": 0.704142},
    "jigsaw": {"mean_auc": 0.722506, "std_auc": 0.105176, "worst_fold_auc": 0.605536},
}

print("Project root:", PROJECT_ROOT)
print("Patch index:", patch_index_csv)
print("Rotation encoder checkpoint:", encoder_checkpoint_path)
# Out:
# Project root: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project
# Patch index: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\data\processed\patches\labeled_patch_index_ps32_common_balanced.csv
# Rotation encoder checkpoint: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\checkpoints\ssl_pretrained\rotation\resnet18_rotation_ps32_encoder_best.pt

# %% [markdown]
# ## 2. Import packages and project modules

# %%
import sys
sys.path.insert(0, str(PROJECT_ROOT))

import numpy as np
import pandas as pd
import torch

from src.patch_dataset import list_raster_files, audit_raster_alignment
from src.models_resnet18 import create_resnet18_binary_classifier, load_ssl_encoder_weights_into_classifier
from src.plotting import set_publication_plot_style
from src.train_finetune import run_pretrained_resnet18_scv_experiment
from src.utils import count_trainable_parameters, set_global_seed

# %% [markdown]
# ## 3. Set random seeds and device

# %%
set_global_seed(random_seed)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
if torch.cuda.is_available():
    print("CUDA GPU:", torch.cuda.get_device_name(0))
    print("torch.version.cuda:", torch.version.cuda)
else:
    print("WARNING: CUDA is not available; training will run on CPU.")
# Out:
# Using device: cuda
# CUDA GPU: NVIDIA GeForce RTX 4090
# torch.version.cuda: 11.8

# %% [markdown]
# ## 4. Set publication-quality plotting style

# %%
plot_font_family = set_publication_plot_style(font_family="Arial", font_size=10)
print("Plotting font family:", plot_font_family)
print("Plotting font size:", 10)
# Out:
# Plotting font family: Arial
# Plotting font size: 10

# %% [markdown]
# ## 5. Load patch index, cleaned rasters, and Rotation pretrained encoder checkpoint

# %%
patch_index = pd.read_csv(patch_index_csv).reset_index(drop=True)
raster_files = list_raster_files(raster_dir)
raster_audit = audit_raster_alignment(raster_files, expected_nodata=-9999)
rotation_checkpoint = torch.load(encoder_checkpoint_path, map_location="cpu")
expected_checkpoint_keys = {
    "encoder_state_dict", "epoch", "val_loss", "val_acc_top1",
    "config", "channel_means", "channel_stds",
}
missing_checkpoint_keys = expected_checkpoint_keys - set(rotation_checkpoint.keys())
if missing_checkpoint_keys:
    raise KeyError(f"Rotation checkpoint missing keys: {sorted(missing_checkpoint_keys)}")
rotation_pretext_val_loss = float(rotation_checkpoint["val_loss"])
rotation_pretext_val_acc_top1 = float(rotation_checkpoint["val_acc_top1"])
print("Patch index rows:", len(patch_index))
print("Raster channels:", len(raster_files))
print("Raster shape:", (raster_audit.height, raster_audit.width))
print("Rotation checkpoint epoch:", rotation_checkpoint.get("epoch"))
print("Rotation pretext val_loss:", rotation_pretext_val_loss)
print("Rotation pretext val_acc_top1:", rotation_pretext_val_acc_top1)
print("Rotation encoder state keys:", len(rotation_checkpoint["encoder_state_dict"]))
print("WARNING: Rotation pretraining learned a strong geometric signal. Downstream performance should determine whether this signal is useful for LSM classification.")
# Out:
# Patch index rows: 344
# Raster channels: 14
# Raster shape: (10071, 9596)
# Rotation checkpoint epoch: 37
# Rotation pretext val_loss: 0.004128127808042336
# Rotation pretext val_acc_top1: 0.9985
# Rotation encoder state keys: 120
# WARNING: Rotation pretraining learned a strong geometric signal. Downstream performance should determine whether this signal is useful for LSM classification.

# %% [markdown]
# ## 6. Verify input data quality

# %%
required_columns = ["sample_id", "x", "y", "label", "source", "cluster_id", "valid_patch", "nodata_ratio"]
missing_columns = [column for column in required_columns if column not in patch_index.columns]
if missing_columns:
    raise ValueError(f"Patch index missing required columns: {missing_columns}")
if not patch_index["valid_patch"].astype(bool).all():
    raise ValueError("Patch index contains invalid patches.")
if not np.isclose(patch_index["nodata_ratio"].to_numpy(dtype="float64"), 0.0).all():
    raise ValueError("Patch index contains nonzero nodata_ratio rows.")
print("total sample count:", len(patch_index))
print("label counts:")
print(patch_index["label"].value_counts().sort_index().to_string())
print("cluster_id x label table:")
print(pd.crosstab(patch_index["cluster_id"], patch_index["label"]).to_string())
print("patch_size:", patch_size)
print("number of raster channels:", len(raster_files))
print("dataset path:", patch_index_csv)
print("Rotation encoder checkpoint path:", encoder_checkpoint_path)
print("Rotation pretext val_loss:", rotation_pretext_val_loss)
print("Rotation pretext val_acc_top1:", rotation_pretext_val_acc_top1)
print("device:", device)
print("batch size:", batch_size)
print("encoder learning rate:", encoder_learning_rate)
print("head learning rate:", head_learning_rate)
print("max epochs:", max_epochs)
print("early stopping patience:", early_stopping_patience)
print("plotting font family and font size:", plot_font_family, 10)
# Out:
# total sample count: 344
# label counts:
# label
# 0    172
# 1    172
# cluster_id x label table:
# label        0   1
# cluster_id
# 0           32  32
# 1           39  39
# 2           53  53
# 3           14  14
# 4           34  34
# patch_size: 32
# number of raster channels: 14
# dataset path: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\data\processed\patches\labeled_patch_index_ps32_common_balanced.csv
# Rotation encoder checkpoint path: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\checkpoints\ssl_pretrained\rotation\resnet18_rotation_ps32_encoder_best.pt
# Rotation pretext val_loss: 0.004128127808042336
# Rotation pretext val_acc_top1: 0.9985
# device: cuda
# batch size: 16
# encoder learning rate: 1e-05
# head learning rate: 0.0001
# max epochs: 100
# early stopping patience: 15
# plotting font family and font size: Arial 10

# %% [markdown]
# ## 7. Define modified ResNet-18 classifier and load Rotation SSL encoder weights

# %%
preview_model = create_resnet18_binary_classifier(in_channels=14, dropout=dropout, small_patch_stem=True, pretrained=False)
preview_load_info = load_ssl_encoder_weights_into_classifier(preview_model, encoder_checkpoint_path, strict_encoder=True)
loaded_preview_keys = len(preview_load_info["loaded_keys"])
if loaded_preview_keys < 110:
    raise RuntimeError(f"Too few Rotation encoder keys loaded: {loaded_preview_keys}")
print("checkpoint epoch:", rotation_checkpoint.get("epoch"))
print("checkpoint val_loss:", rotation_pretext_val_loss)
print("checkpoint val_acc_top1:", rotation_pretext_val_acc_top1)
print("preview loaded pretrained encoder keys:", loaded_preview_keys)
print("model parameter count:", count_trainable_parameters(preview_model))
del preview_model
# Out:
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
# checkpoint epoch: 37
# checkpoint val_loss: 0.004128127808042336
# checkpoint val_acc_top1: 0.9985
# preview loaded pretrained encoder keys: 120
# model parameter count: 11175681

# %% [markdown]
# ## 8. Define SCV fold loop

# %% [markdown]
# Fold loop follows cluster_id 0..4 as held-out test clusters, matching scratch, masked-reconstruction, contrastive, and Jigsaw experiments.

# %% [markdown]
# ## 9. Compute fold-specific channel normalization from training data only

# %% [markdown]
# For fair comparison, supervised fine-tuning normalization is computed from training samples within each fold only. The Rotation SSL checkpoint means/stds are not used for supervised fine-tuning.

# %% [markdown]
# ## 10. Fine-tune fold-specific Rotation-pretrained ResNet-18 models

# %%
scientific_note = "Rotation pretraining was solved almost perfectly as a pretext task, but downstream performance should determine whether this geometric signal is useful for landslide susceptibility classification."
results = run_pretrained_resnet18_scv_experiment(
    project_root=PROJECT_ROOT,
    model_name=model_name,
    pretraining=pretraining,
    patch_index_csv=patch_index_csv,
    raster_dir=raster_dir,
    encoder_checkpoint_path=encoder_checkpoint_path,
    output_root=output_root,
    figure_root=figure_root,
    checkpoint_dir=checkpoint_dir,
    patch_size=patch_size,
    random_seed=random_seed,
    val_fraction=val_fraction,
    batch_size=batch_size,
    encoder_learning_rate=encoder_learning_rate,
    head_learning_rate=head_learning_rate,
    weight_decay=weight_decay,
    max_epochs=max_epochs,
    early_stopping_patience=early_stopping_patience,
    gradient_clip_norm=gradient_clip_norm,
    dropout=dropout,
    reference_metrics=reference_metrics,
    expected_checkpoint_keys=expected_checkpoint_keys,
    checkpoint_extra_values={
        "rotation_pretext_val_loss": rotation_pretext_val_loss,
        "rotation_pretext_val_acc_top1": rotation_pretext_val_acc_top1,
    },
    scientific_note=scientific_note,
    device=device,
    plot_figures=True,
)
fold_metrics = results["fold_metrics"]
summary_df = results["summary_metrics"]
paths = results["paths"]
# Out:
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
#
# ========================================================================
# Fold 0: held-out test cluster 0
# train clusters: [1, 2, 3, 4]
# validation size: 56
# test cluster: 0
# train label counts:
# label
# 0    112
# 1    112
# val label counts:
# label
# 0    28
# 1    28
# test label counts:
# label
# 0    32
# 1    32
# channel means and stds shape: (14,) (14,)
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
# model parameter count: 11175681
# number of trainable parameters: 11175681
# number of loaded pretrained encoder keys: 120
# device sanity model: cuda:0
# device sanity X: cuda:0
# device sanity y: cuda:0
# Fold 0 test AUC: 0.856445; best threshold: 0.118974
#
# ========================================================================
# Fold 1: held-out test cluster 1
# train clusters: [0, 2, 3, 4]
# validation size: 54
# test cluster: 1
# train label counts:
# label
# 0    106
# 1    106
# val label counts:
# label
# 0    27
# 1    27
# test label counts:
# label
# 0    39
# 1    39
# channel means and stds shape: (14,) (14,)
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
# model parameter count: 11175681
# number of trainable parameters: 11175681
# number of loaded pretrained encoder keys: 120
# device sanity model: cuda:0
# device sanity X: cuda:0
# device sanity y: cuda:0
# Fold 1 test AUC: 0.698882; best threshold: 0.653522
#
# ========================================================================
# Fold 2: held-out test cluster 2
# train clusters: [0, 1, 3, 4]
# validation size: 48
# test cluster: 2
# train label counts:
# label
# 0    95
# 1    95
# val label counts:
# label
# 0    24
# 1    24
# test label counts:
# label
# 0    53
# 1    53
# channel means and stds shape: (14,) (14,)
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
# model parameter count: 11175681
# number of trainable parameters: 11175681
# number of loaded pretrained encoder keys: 120
# device sanity model: cuda:0
# device sanity X: cuda:0
# device sanity y: cuda:0
# Fold 2 test AUC: 0.724457; best threshold: 0.260763
#
# ========================================================================
# Fold 3: held-out test cluster 3
# train clusters: [0, 1, 2, 4]
# validation size: 64
# test cluster: 3
# train label counts:
# label
# 0    126
# 1    126
# val label counts:
# label
# 0    32
# 1    32
# test label counts:
# label
# 0    14
# 1    14
# channel means and stds shape: (14,) (14,)
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
# model parameter count: 11175681
# number of trainable parameters: 11175681
# number of loaded pretrained encoder keys: 120
# device sanity model: cuda:0
# device sanity X: cuda:0
# device sanity y: cuda:0
# Fold 3 test AUC: 0.602041; best threshold: 0.237471
#
# ========================================================================
# Fold 4: held-out test cluster 4
# train clusters: [0, 1, 2, 3]
# validation size: 56
# test cluster: 4
# train label counts:
# label
# 0    110
# 1    110
# val label counts:
# label
# 0    28
# 1    28
# test label counts:
# label
# 0    34
# 1    34
# channel means and stds shape: (14,) (14,)
# Loaded SSL encoder keys: 120
# Missing keys after load: 2
# Unexpected/skipped keys: 0
# Expected classifier-head missing keys: ['fc.1.bias', 'fc.1.weight']
# model parameter count: 11175681
# number of trainable parameters: 11175681
# number of loaded pretrained encoder keys: 120
# device sanity model: cuda:0
# device sanity X: cuda:0
# device sanity y: cuda:0
# Fold 4 test AUC: 0.745675; best threshold: 0.192373
# Rotation pretraining was solved almost perfectly as a pretext task, but downstream performance should determine whether this geometric signal is useful for landslide susceptibility classification.

# %% [markdown]
# ## 11. Evaluate fold-specific test performance

# %%
print(fold_metrics[["fold", "auc", "pr_auc", "accuracy_05", "f1_05", "best_threshold_f1", "f1_best_f1", "best_epoch"]].to_string(index=False))
# Out:
#  fold      auc   pr_auc  accuracy_05    f1_05  best_threshold_f1  f1_best_f1  best_epoch
#     0 0.856445 0.815582     0.750000 0.771429           0.118974    0.815789          25
#     1 0.698882 0.702809     0.602564 0.367347           0.653522    0.297872          32
#     2 0.724457 0.689852     0.669811 0.710744           0.260763    0.702703          17
#     3 0.602041 0.602802     0.500000 0.533333           0.237471    0.666667           9
#     4 0.745675 0.698509     0.632353 0.545455           0.192373    0.684932          13

# %% [markdown]
# ## 12. Save predictions, metrics, logs, and checkpoints

# %%
prediction_columns = ["sample_id", "x", "y", "label", "source", "cluster_id", "fold", "y_true", "y_logit", "y_prob", "y_pred_05", "y_pred_best_f1", "split"]
metric_columns = ["model", "pretraining", "patch_size", "fold", "n_train", "n_val", "n_test", "n_test_pos", "n_test_neg", "auc", "pr_auc", "accuracy_05", "precision_05", "recall_05", "f1_05", "best_threshold_f1", "accuracy_best_f1", "precision_best_f1", "recall_best_f1", "f1_best_f1", "tn", "fp", "fn", "tp", "best_epoch", "best_val_auc", "best_val_loss"]
if list(fold_metrics.columns) != metric_columns:
    raise ValueError("Fold metrics schema mismatch.")
for fold_id in range(5):
    pred_path = output_root / "predictions" / f"rotation_resnet18_ps32_fold{fold_id}_predictions.csv"
    log_path = output_root / "training_logs" / f"rotation_resnet18_ps32_fold{fold_id}_training_log.csv"
    ckpt_path = checkpoint_dir / f"rotation_resnet18_ps32_fold{fold_id}_best.pt"
    pred = pd.read_csv(pred_path)
    if list(pred.columns) != prediction_columns:
        raise ValueError(f"Prediction columns mismatch for fold {fold_id}.")
    log = pd.read_csv(log_path)
    for column in ["epoch", "train_loss", "val_loss", "train_auc", "val_auc", "train_f1", "val_f1", "learning_rate", "encoder_learning_rate", "head_learning_rate"]:
        if column not in log.columns:
            raise ValueError(f"Training log fold {fold_id} missing {column}.")
    ckpt = torch.load(ckpt_path, map_location="cpu")
    for key in ["model_state_dict", "optimizer_state_dict", "epoch", "best_val_auc", "best_val_loss", "fold", "patch_size", "model_name", "pretraining_type", "encoder_checkpoint_path", "rotation_pretext_val_loss", "rotation_pretext_val_acc_top1", "channel_means", "channel_stds", "config"]:
        if key not in ckpt:
            raise KeyError(f"Checkpoint fold {fold_id} missing key {key}.")
print("Prediction files, training logs, fold metrics, summary metrics, and checkpoints passed schema checks.")
print("Fold metrics:", paths["fold_metrics"])
print("Summary metrics:", paths["summary_metrics"])
# Out:
# Prediction files, training logs, fold metrics, summary metrics, and checkpoints passed schema checks.
# Fold metrics: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\metrics\rotation_resnet18_ps32_fold_metrics.csv
# Summary metrics: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\metrics\rotation_resnet18_ps32_summary_metrics.csv

# %% [markdown]
# ## 13. Plot ROC, PR, and training curves using standardized figure style

# %%
figure_paths = [
    figure_root / "roc_curves/rotation_resnet18_ps32_roc_all_folds.png",
    figure_root / "roc_curves/rotation_resnet18_ps32_roc_all_folds.pdf",
    figure_root / "pr_curves/rotation_resnet18_ps32_pr_all_folds.png",
    figure_root / "pr_curves/rotation_resnet18_ps32_pr_all_folds.pdf",
    figure_root / "training_curves/rotation_resnet18_ps32_training_curves.png",
    figure_root / "training_curves/rotation_resnet18_ps32_training_curves.pdf",
]
for path in figure_paths:
    if not path.exists():
        raise FileNotFoundError(path)
    print(path)
# Out:
# D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation\roc_curves\rotation_resnet18_ps32_roc_all_folds.png
# D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation\roc_curves\rotation_resnet18_ps32_roc_all_folds.pdf
# D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation\pr_curves\rotation_resnet18_ps32_pr_all_folds.png
# D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation\pr_curves\rotation_resnet18_ps32_pr_all_folds.pdf
# D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation\training_curves\rotation_resnet18_ps32_training_curves.png
# D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation\training_curves\rotation_resnet18_ps32_training_curves.pdf

# %% [markdown]
# ## 14. Compare summary metrics against scratch, masked-recon, contrastive, and Jigsaw baselines

# %%
summary = summary_df.iloc[0].to_dict()
print(summary_df.T.to_string(header=False))
# Out:
# mean_auc                                    0.7255
# std_auc                                   0.091522
# mean_pr_auc                               0.701911
# std_pr_auc                                0.075666
# mean_accuracy_05                          0.630946
# std_accuracy_05                           0.091704
# mean_precision_05                         0.691433
# std_precision_05                          0.145365
# mean_recall_05                            0.579689
# std_recall_05                              0.25709
# mean_f1_05                                0.585661
# std_f1_05                                 0.159821
# mean_accuracy_best_f1                     0.635254
# std_accuracy_best_f1                      0.089483
# mean_precision_best_f1                    0.662679
# std_precision_best_f1                     0.136327
# mean_recall_best_f1                       0.744361
# std_recall_best_f1                        0.331019
# mean_f1_best_f1                           0.633593
# std_f1_best_f1                            0.196475
# model                            rotation_resnet18
# pretraining                               rotation
# patch_size                                      32
# worst_fold_auc                            0.602041
# best_fold_auc                             0.856445
# worst_fold                                       3
# best_fold                                        0
# rotation_pretext_val_loss                 0.004128
# rotation_pretext_val_acc_top1               0.9985
# scratch_mean_auc                          0.778842
# scratch_std_auc                           0.104754
# scratch_worst_fold_auc                    0.624023
# delta_mean_auc_vs_scratch                -0.053342
# delta_std_auc_vs_scratch                 -0.013232
# delta_worst_auc_vs_scratch               -0.021982
# masked_recon_mean_auc                     0.820912
# masked_recon_std_auc                      0.043011
# masked_recon_worst_fold_auc               0.786325
# delta_mean_auc_vs_masked_recon           -0.095412
# delta_std_auc_vs_masked_recon             0.048511
# delta_worst_auc_vs_masked_recon          -0.184284
# contrastive_mean_auc                      0.838008
# contrastive_std_auc                       0.084941
# contrastive_worst_fold_auc                0.704142
# delta_mean_auc_vs_contrastive            -0.112508
# delta_std_auc_vs_contrastive              0.006581
# delta_worst_auc_vs_contrastive           -0.102101
# jigsaw_mean_auc                           0.722506
# jigsaw_std_auc                            0.105176
# jigsaw_worst_fold_auc                     0.605536
# delta_mean_auc_vs_jigsaw                  0.002994
# delta_std_auc_vs_jigsaw                  -0.013654
# delta_worst_auc_vs_jigsaw                -0.003495

# %% [markdown]
# ## 15. Print final summary and scientific interpretation

# %%
mean_std_table = pd.DataFrame({
    "metric": ["auc", "pr_auc", "accuracy_05", "f1_05", "accuracy_best_f1", "f1_best_f1"],
    "mean": [summary[f"mean_{m}"] for m in ["auc", "pr_auc", "accuracy_05", "f1_05", "accuracy_best_f1", "f1_best_f1"]],
    "std": [summary[f"std_{m}"] for m in ["auc", "pr_auc", "accuracy_05", "f1_05", "accuracy_best_f1", "f1_best_f1"]],
})
print("Fold-wise metrics table:")
print(fold_metrics[["fold", "auc", "pr_auc", "accuracy_05", "f1_05", "accuracy_best_f1", "f1_best_f1"]].to_string(index=False))
print("\nMean +/- std metrics:")
print(mean_std_table.to_string(index=False))
print("\nWorst fold by AUC:", summary["worst_fold"], summary["worst_fold_auc"])
print("Best fold by AUC:", summary["best_fold"], summary["best_fold_auc"])
for ref_name, ref in reference_metrics.items():
    print(f"{ref_name} baseline mean_auc/std_auc:", ref["mean_auc"], ref["std_auc"])
print("Rotation mean_auc/std_auc:", summary["mean_auc"], summary["std_auc"])
for key in ["delta_mean_auc_vs_scratch", "delta_std_auc_vs_scratch", "delta_worst_auc_vs_scratch", "delta_mean_auc_vs_masked_recon", "delta_std_auc_vs_masked_recon", "delta_worst_auc_vs_masked_recon", "delta_mean_auc_vs_contrastive", "delta_std_auc_vs_contrastive", "delta_worst_auc_vs_contrastive", "delta_mean_auc_vs_jigsaw", "delta_std_auc_vs_jigsaw", "delta_worst_auc_vs_jigsaw"]:
    print(key + ":", summary[key])
print("\nSaved output locations:")
for key, value in paths.items():
    print(key + ":", value)
print("\nScientific note:", scientific_note)
# Out:
# Fold-wise metrics table:
#  fold      auc   pr_auc  accuracy_05    f1_05  accuracy_best_f1  f1_best_f1
#     0 0.856445 0.815582     0.750000 0.771429          0.781250    0.815789
#     1 0.698882 0.702809     0.602564 0.367347          0.576923    0.297872
#     2 0.724457 0.689852     0.669811 0.710744          0.584906    0.702703
#     3 0.602041 0.602802     0.500000 0.533333          0.571429    0.666667
#     4 0.745675 0.698509     0.632353 0.545455          0.661765    0.684932
#
# Mean +/- std metrics:
#           metric     mean      std
#              auc 0.725500 0.091522
#           pr_auc 0.701911 0.075666
#      accuracy_05 0.630946 0.091704
#            f1_05 0.585661 0.159821
# accuracy_best_f1 0.635254 0.089483
#       f1_best_f1 0.633593 0.196475
#
# Worst fold by AUC: 3 0.6020408163265306
# Best fold by AUC: 0 0.8564453125
# scratch baseline mean_auc/std_auc: 0.778842 0.104754
# masked_recon baseline mean_auc/std_auc: 0.820912 0.043011
# contrastive baseline mean_auc/std_auc: 0.838008 0.084941
# jigsaw baseline mean_auc/std_auc: 0.722506 0.105176
# Rotation mean_auc/std_auc: 0.7255000571498961 0.09152247522098715
# delta_mean_auc_vs_scratch: -0.05334194285010396
# delta_std_auc_vs_scratch: -0.013231524779012849
# delta_worst_auc_vs_scratch: -0.02198218367346938
# delta_mean_auc_vs_masked_recon: -0.0954119428501039
# delta_std_auc_vs_masked_recon: 0.04851147522098715
# delta_worst_auc_vs_masked_recon: -0.18428418367346944
# delta_mean_auc_vs_contrastive: -0.1125079428501039
# delta_std_auc_vs_contrastive: 0.0065814752209871485
# delta_worst_auc_vs_contrastive: -0.10210118367346943
# delta_mean_auc_vs_jigsaw: 0.00299405714989609
# delta_std_auc_vs_jigsaw: -0.013653524779012854
# delta_worst_auc_vs_jigsaw: -0.0034951836734693487
#
# Saved output locations:
# prediction_dir: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\predictions
# metrics_dir: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\metrics
# training_log_dir: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\training_logs
# checkpoint_dir: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\checkpoints\finetuned\rotation_resnet18
# figure_root: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\figures\R1_ssl_task_comparison\rotation
# fold_metrics: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\metrics\rotation_resnet18_ps32_fold_metrics.csv
# summary_metrics: D:\SBU first year\First year paper\LSM_SSL_ResNet18_Project\outputs\R1_ssl_task_comparison\rotation\metrics\rotation_resnet18_ps32_summary_metrics.csv
#
# Scientific note: Rotation pretraining was solved almost perfectly as a pretext task, but downstream performance should determine whether this geometric signal is useful for landslide susceptibility classification.
